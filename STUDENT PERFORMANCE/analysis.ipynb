# %%
import pandas as pd
import missingno as mso
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Checks to Perform
# **Check missing values**
# **Check Duplicates**
# **Check Datatype**
# **Check the number of unique values in each column**
# **Check statistics of dataset**
# **Check various categories in different columns**

# %% [markdown]
# **Reading the csv file and creating dataframe**

# %%
df=pd.read_csv('StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
df.shape
# Out:
# (1000, 8)

# %% [markdown]
# **Checking Missing Values in Dataset**

# %%
mso.matrix(df,figsize=(5,5))
# Out:
# <Axes: >

# %%
df.isnull().sum() # it counts total number of missing values in each column of the DataFrame
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# **Analysis Result :**
# *Using missingno library and isnull() and info() method of Pandas , we are sure that there is no Missing Values in Dataset*

# %% [markdown]
# **Checking Duplicates in the Dataset**

# %%
df.duplicated().sum() # returns the count of total duplicated rows
# Out:
# 0

# %% [markdown]
# **Analysis Result :**
# *Using the duplicated() method of pandas, we analysed that there is no duplicated rows in the Dataset*

# %% [markdown]
# **Check the datatype**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# **Analysis :**
# *Using the info() method of Pandas, we have analysed that there are five categorical and 3 integer columns*
# *Categorical - gender, race, parental level of education, lunch ,test preparation score*
# *Integer/Continuous - Math score, reading score, writing score*

# %% [markdown]
# **Checking the number of unique values in each column**

# %%
df.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %% [markdown]
# **Analysis :**
# *Using the nunique() of Pandas, we have analysed number of unique values in each column*
# *For ex: There are 2 uniques values in gender column , male and female*
# *Similarily, there are 5 unique values in race/ethnicity column and so on..*

# %% [markdown]
# **Check Statistics of Dataset**

# %% [markdown]
# *Calculating Mean of reading , writing and math score*

# %%
math_mean_score=df['math score'].mean()
print(math_mean_score)

writing_mean_score=df['writing score'].mean()
print(writing_mean_score)

reading_mean_score=df['reading score'].mean()
print(reading_mean_score)
# Out:
# 66.089
# 68.054
# 69.169

# %% [markdown]
# *Calculating Median of reading, writing and math score*

# %%
math_median=df['math score'].median()
print(math_median)

writing_median=df['writing score'].median()
print(writing_median)

reading_median=df['reading score'].median()
print(reading_median)
# Out:
# 66.0
# 69.0
# 70.0

# %% [markdown]
# *Calculating Mode of reading , writing and math score*

# %%
math_mode=df['math score'].mode()
print(math_mode)

writing_mode=df['writing score'].mode()
print(writing_mode)

reading_mode=df['reading score'].mode()
print(reading_mode)
# Out:
# 0    65
# Name: math score, dtype: int64
# 0    74
# Name: writing score, dtype: int64
# 0    72
# Name: reading score, dtype: int64

# %% [markdown]
# *Calculating Range i.e. difference between max and min values of reading, writing and math score*

# %%
m_max=df['math score'].max() # 100
m_min=df['math score'].min() # 0

math_score_range=m_max-m_min
print(math_score_range)


r_max=df['reading score'].max() # 100
r_min=df['reading score'].min() # 17

reading_score_range=r_max-r_min
print(reading_score_range)

w_max=df['writing score'].max() # 100
w_min=df['writing score'].min() # 10

writing_score_range=w_max-w_min
print(writing_score_range)
# Out:
# 100
# 83
# 90

# %% [markdown]
# *Using the describe() of Pandas, we have analysed various features like count,mean,std,min,etc...*

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %% [markdown]
# **Co-relation Analysis**

# %%
m1=df['math score'].corr(df['writing score'])
m2=df['math score'].corr(df['reading score'])

print(m1,m2)
# Out:
# 0.8026420459498085 0.8175796636720544

# %%
w1=df['writing score'].corr(df['math score'])
w2=df['writing score'].corr(df['reading score'])

print(w1,w2)
# Out:
# 0.8026420459498085 0.9545980771462478

# %%
r1=df['reading score'].corr(df['math score'])
r2=df['reading score'].corr(df['writing score'])

print(r1,r2)
# Out:
# 0.8175796636720544 0.9545980771462478

# %% [markdown]
# **Analysis  :**
# *Using the corr() of Pandas, we have analysed that math score , reading and writing score are dependent on each other.*
# *For ex: one who has good writing score have 95% probability that he/she will have good reading score too.*

# %% [markdown]
# *Getting Numerical Features*

# %%
numeric_features=df.select_dtypes(include=['int','float'])
print(numeric_features)
# Out:
#      math score  reading score  writing score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %% [markdown]
# *Getting Categorical/Object Features*

# %%
categorical_features=df.select_dtypes(include='object')
print(categorical_features)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course
# 0                      none
# 1                 completed
# 2                      none
# 3                      none
# 4                      none
# ..                      ...
# 995               completed
# 996                    none
# 997               completed
# 998               completed
# 999                    none
#
# [1000 rows x 5 columns]

# %% [markdown]
# **Analysis using Various Plots**

# %% [markdown]
# When you call plt.subplots(), it creates two things:
#
# Figure (fig): This represents the entire canvas or window where your plots will be drawn. It's like the blank sheet of paper on which you're going to make your drawings.
#
# Axes (ax): This is an array of axes objects, where each element of the array represents a subplot within the figure. You can think of each subplot as an individual plot or chart that you can customize and add data to.
#
# So, in summary:
#
# fig is the entire figure or canvas.
# ax is an array of axes objects, each representing a subplot within the figure.
# You can then use these fig and ax objects to create and customize your plots as needed.

# %% [markdown]
# *Pie Chart*
# *Gender - Showing distribution of Gender in Dataset using Pie Chart*

# %%
gender_count=df['gender'].value_counts()
labels=['Female','Male']
explode=(0.03,0)
# print(gender_count)
# print(type(gender_count))

"""plt.plot() creates the plots and stores them internally, while plt.show() is used to actually display those plots."""
fig,ax=plt.subplots()
ax.pie(gender_count, labels=labels, startangle=90, autopct='%1.1f%%',textprops={'color': 'white'}, explode=explode)
ax.set_title("Gender",fontsize=20)
ax.title.set_color('white')
fig.set_facecolor('none')

plt.show()

# %% [markdown]
# **Analysis :**
# *Here, we have analysed that out of 1000 , 518 are females (51.2%) and rest 482 are males (48.2%)*

# %% [markdown]
# *Race/Ethnicity - Showing the Distribution of Race over the dataset using Pie Chart*

# %%
race_counts=df['race/ethnicity'].value_counts()
labels=['group C','group D','group B','group E','group A']
explode=(0.1,0,0,0,0)
# print(race_counts)
# print(type(race_counts))

fig,ax=plt.subplots()
ax.pie(race_counts,labels=labels,autopct='%1.1f%%',textprops={"color":'white'},explode=explode)
ax.set_title('Race/Ethnicity',fontsize=20)
ax.title.set_color('white')
fig.set_facecolor('none')

plt.show()

# %% [markdown]
# **Analysis :**
# *Here we have analysed that out of 1000 people, 319 belongs to group C, 262 belongs to group D, 190 belongs to group B, 140 belongs to group E and 89 belongs to group A.*

# %% [markdown]
# *Parental Level of Education - Showing the Distribution of Parental Level of Education over the dataset.*

# %%
education=df['parental level of education'].value_counts()
# print(education)
# print(type(education))
labels=['some college',"associate's degree",'high school','some high school',"bachelor's degree","master's degree"]
explode=[0,0.1,0,0,0.1,0.1]

fig,ax=plt.subplots()
ax.pie(education,labels=labels,autopct='%1.1f%%',textprops={'color':'white'},explode=explode)
ax.set_title("Parental Level of Education",fontsize=20)
ax.title.set_color('white')
fig.set_facecolor('none')
plt.show()

# %% [markdown]
# **Analysis :**
# *Here we have analysed that 22.2% parents have Associate's Degree, 22.6% have some college Degree, 5.9% parents have master's Degree, 11.8% parents have Bachelor's Degree and 17.9% parents went to some high school, and 19.6% parents went to high school.*

# %% [markdown]
# *Lunch - Showing the Distribution of Lunch over the dataset.*

# %%
lunch_count=df['lunch'].value_counts()
# print(lunch_count)
# print(type(lunch_count))
labels=['standard','free/reduced']
explode=[0.1,0]

fig,ax=plt.subplots()
ax.pie(lunch_count,labels=labels,autopct='%1.1f%%',explode=explode,textprops={'color':'white'})
ax.set_title("Lunch",fontsize=20)
ax.title.set_color('white')
fig.set_facecolor('none')
plt.show()

# %% [markdown]
# **Analysis :**
#
# *Here we analysed that out of 1000 students, 645 students received standard lunch and 355 students received free/reduced lunch*

# %% [markdown]
# *Test Preparation Course - Showing the Distribution of Test Preparation Course over Dataset*

# %%
test_counts=df['test preparation course'].value_counts()
# print(test_counts)
# print(type(test_counts))
labels=['none','completed']
explode=[0.07,0]

fig,ax=plt.subplots()
ax.pie(test_counts,labels=labels,autopct='%1.1f%%',explode=explode,textprops={'color':'white'})
ax.set_title("Test Preparation Course")
ax.title.set_color('white')
fig.set_facecolor('none')
plt.show()

# %% [markdown]
# **Analysis :**
# *Here we have analysed that out of 1000 students, 642 students didnt completed their test preparation course whereas 358 students did complete their test preparation course*

# %% [markdown]
# **Creating 2 new columns representing total marks and percentage gained in math , reading and writing.**

# %%
df['total marks']=df['math score']+df['reading score']+df['writing score']
df['percentage']=round(df['total marks']*100/300,2)

# %% [markdown]
# **Analysing the impact of various features such as gender, race, parent's education, lunch, test preparation course on math score, reading score, writing score, total marks.**

# %%
x_category=['gender','race/ethnicity','parental level of education','lunch','test preparation course']
y_category=['math score','reading score','writing score','total marks']

# %% [markdown]
# **Gender vs Marks - Analysing the impact of gender over math score, reading score, writing score and total marks**

# %%
fig,ax=plt.subplots(1,len(y_category),figsize=(20,4))
# ax=plt.subplot(1,4,i+1)

for i in range(len(y_category)):
    sns.boxplot(x=df['gender'],y=df[y_category[i]],ax=ax[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# **Race vs Marks -  Analysing the impact of Race over math score, reading score, writing score and total marks**

# %%
y_category=['math score','reading score','writing score','total marks']
fig,ax=plt.subplots(1,len(y_category),figsize=(20,4))
# ax=plt.subplot(1,4,i+1)

for i in range(len(y_category)):
    sns.boxplot(x=df['race/ethnicity'],y=df[y_category[i]],ax=ax[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# **Parental Education vs Marks**

# %%
y_category=['math score','reading score','writing score','total marks']

for i in range(len(y_category)):
    sns.boxplot(x=df['parental level of education'],y=df[y_category[i]])
    plt.xticks(rotation=45)
    plt.show()

# plt.tight_layout()

# %% [markdown]
# **Lunch vs Marks - Analysing the impact of Lunch over math score, reading score, writing score and total marks**

# %%
fig,ax=plt.subplots(1,len(y_category),figsize=(20,5))

for i in range(len(y_category)):
    sns.boxplot(x=df['lunch'],y=df[y_category[i]],ax=ax[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# **Test Preparation Course vs Marks - Analysis of Test Preparation course over math score, reading score, writing score and total marks**

# %%
fig,ax=plt.subplots(1,len(y_category),figsize=(20,5))

for i in range(len(y_category)):
    sns.boxplot(x=df['test preparation course'],y=df[y_category[i]],ax=ax[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# **Test Preparation Course vs Test Score Comparison**

# %%
plt.figure(figsize=(12,6))
plt.subplot(2,2,1)
sns.barplot(x=df['test preparation course'],y=df['math score'])
plt.subplot(2,2,2)
sns.barplot(x=df['test preparation course'],y=df['reading score'])
plt.subplot(2,2,3)
sns.barplot(x=df['test preparation course'],y=df['writing score'])
plt.subplot(2,2,4)
sns.barplot(x=df['test preparation course'], y=df['total marks'])

plt.show()

# %% [markdown]
# **Analysis :**
# *Here, we have analysed that students who have completed their Test Preparation Course have scored better in every subjects as compared to students who haven't completed their Test Preparation Course*

# %% [markdown]
# **Lunch vs Test Score Comparison**

# %%
plt.figure(figsize=(12,6))
plt.subplot(2,2,1)
sns.barplot(x=df['lunch'],y=df['math score'])
plt.subplot(2,2,2)
sns.barplot(x=df['lunch'],y=df['reading score'])
plt.subplot(2,2,3)
sns.barplot(x=df['lunch'],y=df['writing score'])
plt.subplot(2,2,4)
sns.barplot(x=df['lunch'], y=df['total marks'])

plt.show()

# %% [markdown]
# **Analysis :**
# *Here we have analysed that students who received standard lunch performed better than students who received free/reduced lunch in all subjects*

# %% [markdown]
# **Parental Level of Education vs Test Score Comparisons**

# %%
plt.figure(figsize=(12,24)) # figsize=(width,height)
plt.subplot(2,2,1)
sns.barplot(x=df['parental level of education'],y=df['math score'])
plt.xticks(rotation=45)

plt.subplot(2,2,2)
sns.barplot(x=df['parental level of education'],y=df['reading score'])
plt.xticks(rotation=45)

plt.subplot(2,2,3)
sns.barplot(x=df['parental level of education'],y=df['writing score'])
plt.xticks(rotation=45)

plt.subplot(2,2,4)
sns.barplot(x=df['parental level of education'], y=df['total marks'])
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# **Analysis :**
# *Here, we have analysed that students whose parents have Master's or Bachelor's Degree have performed better than other students whose parents have got other formal education*

# %% [markdown]
# **Gender vs Test Scores**

# %%
plt.figure(figsize=(12,6)) # width=12 inches height=6 inches
plt.subplot(2,2,1)
sns.barplot(x=df['gender'],y=df['math score'])
plt.subplot(2,2,2)
sns.barplot(x=df['gender'],y=df['reading score'])
plt.subplot(2,2,3)
sns.barplot(x=df['gender'],y=df['writing score'])
plt.subplot(2,2,4)
sns.barplot(x=df['gender'], y=df['total marks'])

plt.show()

# %% [markdown]
# **Analysis :**
# *Here, we have analysed that male have performed better than females in Math subject whereas females have performed better in Reading , writing and have better overvall marks than males*

# %% [markdown]
# **Race/Ethnicity vs Test Scores**

# %%
plt.figure(figsize=(12,6)) # figsize=(width,height)
plt.subplot(2,2,1)
sns.barplot(x=df['race/ethnicity'],y=df['math score'])
# plt.xticks(rotation=45)

plt.subplot(2,2,2)
sns.barplot(x=df['race/ethnicity'],y=df['reading score'])
# plt.xticks(rotation=45)

plt.subplot(2,2,3)
sns.barplot(x=df['race/ethnicity'],y=df['writing score'])
# plt.xticks(rotation=45)

plt.subplot(2,2,4)
sns.barplot(x=df['race/ethnicity'], y=df['total marks'])
# plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# **Analysis :**
# *Here, we have analysed that students who belong to Group E Race have performed better in all subjects than any other race students.*
